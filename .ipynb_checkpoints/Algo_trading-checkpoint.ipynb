# %%
import yfinance as yf 
import datetime
import pandas as pd
import numpy as np
import datetime

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-0.1.59-py2.py3-none-any.whl
# Requirement already satisfied: lxml>=4.5.1 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from yfinance) (1.20.1)
# Requirement already satisfied: pandas>=0.24 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from yfinance) (1.2.4)
# Requirement already satisfied: requests>=2.20 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from yfinance) (2.25.1)
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.9-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from pandas>=0.24->yfinance) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from requests>=2.20->yfinance) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from requests>=2.20->yfinance) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/shanshanzhang/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages (from requests>=2.20->yfinance) (2.10)
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.59
# Note: you may need to restart the kernel to use updated packages.

# %%
data = yf.download('BTC-USD',  '2021-02-08','2021-02-14', interval="1m")
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BTC-USD: 1m data not available for startTime=1612702800 and endTime=1613221200. The requested range must be within the last 30 days.

# %%
BTC = yf.Ticker("BTC-USD")

df_BTC = BTC.history(start = '2020-04-8', end='2021-4-09')
df_BTC.drop(columns=['Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_BTC['daily_return'] = df_BTC['Close'].dropna().pct_change()
df_BTC.head()
# Out:
#                    Open         High          Low        Close       Volume  \
# Date
# 2020-04-07  7273.644043  7427.939453  7136.714355  7176.414551  44243482668
# 2020-04-08  7179.283203  7356.223633  7153.305664  7334.098633  37563249549
# 2020-04-09  7337.966309  7341.448242  7179.094238  7302.089355  34815139178
# 2020-04-10  7303.815430  7303.815430  6802.475098  6865.493164  43622840992
# 2020-04-11  6867.440430  6926.069824  6789.920898  6859.083008  31222085946
#
#             daily_return
# Date
# 2020-04-07           NaN
# 2020-04-08      0.021973
# 2020-04-09     -0.004364
# 2020-04-10     -0.059791
# 2020-04-11     -0.000934

# %%
# Grab just the `date` and `close` from the IEX dataset
signals_df = df_BTC.loc[:, ["Close"]].copy()

# Set the short window and long windows
short_window = 50
long_window = 100

# Generate the short and long moving averages (50 and 100 days, respectively)
signals_df["SMA50"] = signals_df["Close"].rolling(window=short_window).mean()
signals_df["SMA100"] = signals_df["Close"].rolling(window=long_window).mean()

# Initialize the new `Signal` column
signals_df["Signal"] = 0.0

# Generate the trading signal 0 or 1,
# where 0 is when the SMA50 is under the SMA100, and
# where 1 is when the SMA50 is higher (or crosses over) the SMA100
signals_df["Signal"][short_window:] = np.where(
    signals_df["SMA50"][short_window:] < signals_df["SMA100"][short_window:], 1.0, 0.0
)

# Calculate the points in time at which a position should be taken, 1 or -1
signals_df["Entry/Exit"] = signals_df["Signal"].diff()

# Print the DataFrame
signals_df.head(10)
# Out:
#                   Close  SMA50  SMA100  Signal  Entry/Exit
# Date
# 2020-04-07  7176.414551    NaN     NaN     0.0         NaN
# 2020-04-08  7334.098633    NaN     NaN     0.0         0.0
# 2020-04-09  7302.089355    NaN     NaN     0.0         0.0
# 2020-04-10  6865.493164    NaN     NaN     0.0         0.0
# 2020-04-11  6859.083008    NaN     NaN     0.0         0.0
# 2020-04-12  6971.091797    NaN     NaN     0.0         0.0
# 2020-04-13  6845.037598    NaN     NaN     0.0         0.0
# 2020-04-14  6842.427734    NaN     NaN     0.0         0.0
# 2020-04-15  6642.109863    NaN     NaN     0.0         0.0
# 2020-04-16  7116.804199    NaN     NaN     0.0         0.0

# %%
# Visualize exit position relative to close price
exit = signals_df[signals_df['Entry/Exit'] == -1.0]['Close'].hvplot.scatter(
    color='red',
    marker='v',
    size=200,
    legend=False,
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize entry position relative to close price
entry = signals_df[signals_df['Entry/Exit'] == 1.0]['Close'].hvplot.scatter(
    color='green',
    marker='^',
    size=200,
    legend=False,
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize close price for the investment
security_close = signals_df[['Close']].hvplot(
    line_color='lightgray',
    ylabel='Price in $',
    width=1000,
    height=400
)

# Visualize moving averages
moving_avgs = signals_df[['SMA50', 'SMA100']].hvplot(
    ylabel='Price in $',
    width=1000,
    height=400
)

# Overlay plots
entry_exit_plot = security_close * moving_avgs * entry * exit
entry_exit_plot.opts(xaxis=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-0bad62fc943e> in <module>
#       1 # Visualize exit position relative to close price
# ----> 2 exit = signals_df[signals_df['Entry/Exit'] == -1.0]['Close'].hvplot.scatter(
#       3     color='red',
#       4     marker='v',
#       5     size=200,
#
# ~/opt/anaconda3/envs/algotrading/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'hvplot'

# %%
# Set initial capital
initial_capital = float(100000)

# Set the share size
share_size = -500

# Take a 500 share position where the dual moving average crossover is 1 (SMA50 is greater than SMA100)
signals_df["Position"] = share_size * signals_df["Signal"]

# Find the points in time where a 500 share position is bought or sold
signals_df["Entry/Exit Position"] = signals_df["Position"].diff()

# Multiply share price by entry/exit positions and get the cumulatively sum
signals_df["Portfolio Holdings"] = (
    signals_df["Close"] * signals_df["Entry/Exit Position"].cumsum()
)

# Subtract the initial capital by the portfolio holdings to get the amount of liquid cash in the portfolio
signals_df["Portfolio Cash"] = (
    initial_capital - (signals_df["Close"] * signals_df["Entry/Exit Position"]).cumsum()
)

# Get the total portfolio value by adding the cash amount by the portfolio holdings (or investments)
signals_df["Portfolio Total"] = (
    signals_df["Portfolio Cash"] + signals_df["Portfolio Holdings"]
)

# Calculate the portfolio daily returns
signals_df["Portfolio Daily Returns"] = signals_df["Portfolio Total"].pct_change()

# Calculate the cumulative returns
signals_df["Portfolio Cumulative Returns"] = (
    1 + signals_df["Portfolio Daily Returns"]
).cumprod() - 1

# Print the DataFrame
signals_df.tail()
# Out:
#                    Close         SMA50        SMA100  Signal  Entry/Exit  \
# Date
# 2021-04-04  58758.554688  53929.927422  44771.651152     0.0         0.0
# 2021-04-05  59057.878906  54136.739219  45097.859570     0.0         0.0
# 2021-04-06  58192.359375  54341.685234  45417.060215     0.0         0.0
# 2021-04-07  56048.937500  54478.666563  45706.701504     0.0         0.0
# 2021-04-08  58323.953125  54602.165469  46016.316660     0.0         0.0
#
#             Position  Entry/Exit Position  Portfolio Holdings  Portfolio Cash  \
# Date
# 2021-04-04      -0.0                  0.0                 0.0   -261339.84375
# 2021-04-05      -0.0                  0.0                 0.0   -261339.84375
# 2021-04-06      -0.0                  0.0                 0.0   -261339.84375
# 2021-04-07      -0.0                  0.0                 0.0   -261339.84375
# 2021-04-08      -0.0                  0.0                 0.0   -261339.84375
#
#             Portfolio Total  Portfolio Daily Returns  \
# Date
# 2021-04-04    -261339.84375                      0.0
# 2021-04-05    -261339.84375                      0.0
# 2021-04-06    -261339.84375                      0.0
# 2021-04-07    -261339.84375                      0.0
# 2021-04-08    -261339.84375                      0.0
#
#             Portfolio Cumulative Returns
# Date
# 2021-04-04                     -3.613398
# 2021-04-05                     -3.613398
# 2021-04-06                     -3.613398
# 2021-04-07                     -3.613398
# 2021-04-08                     -3.613398

# %%
# Initialize trade evaluation DataFrame with columns
trade_evaluation_df = pd.DataFrame(
    columns=[
        'Cypto', 
        'Entry Date', 
        'Exit Date', 
        'Shares', 
        'Entry Share Price', 
        'Exit Share Price', 
        'Entry Portfolio Holding', 
        'Exit Portfolio Holding', 
        'Profit/Loss']
)

trade_evaluation_df
# Out:
# Empty DataFrame
# Columns: [Cypto, Entry Date, Exit Date, Shares, Entry Share Price, Exit Share Price, Entry Portfolio Holding, Exit Portfolio Holding, Profit/Loss]
# Index: []

# %%
price_df = signals_df[['Close', 'SMA50', 'SMA100']]

price_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
